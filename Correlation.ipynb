# %% [markdown]
# <a href="https://colab.research.google.com/github/mrcoding16/Reinforment_Learning/blob/main/Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import random
l1 = [random.randint(x,100) for x in range(0,100)]
l2 = [random.randint(x,100) for x in range(0,100)]
plt.scatter(l1,l2)

# %%
l3 = [x for x in range(0,12)]
l4 = [x+12 for x in range(0,12)]

l5 = [abs(x-12) for x in range(0,12)]
plt.subplot(1,2,1)
plt.scatter(l3,l4)
plt.subplot(1,2,2)
plt.scatter(l3,l5)

# %%
import numpy as np

arr1 = np.array(l1)
arr2 = np.array(l2)

rel = np.corrcoef(arr1,arr2)

print(rel)
plt.plot(rel)
# Out:
# [[1.         0.45919855]
#  [0.45919855 1.        ]]
# [<matplotlib.lines.Line2D at 0x7a026f7cace0>,
#  <matplotlib.lines.Line2D at 0x7a026f7cad40>]

# %%
arr1 = np.array(np.random.randint((1000), size=(500)))
arr2 = np.array(np.random.choice((arr1*57), size=(500)))
arr3 = np.array(np.random.choice((-(arr1*75)), size=(500)))
arr4 = np.array(np.random.randint((1000), size=(500)))
plt.figure(figsize=(10,7))
plt.subplot(1,2,1)
plt.scatter(arr1,arr2)
plt.subplot(1,2,2)
plt.scatter(arr1,arr3)

# %%
rel = np.corrcoef(arr1,arr2)
print(rel)
plt.plot(rel)
# Out:
# [[ 1.         -0.05558995]
#  [-0.05558995  1.        ]]
# [<matplotlib.lines.Line2D at 0x7a026c7a2e00>,
#  <matplotlib.lines.Line2D at 0x7a026c7a2e60>]

# %%
import pandas as pd

df = pd.DataFrame({"A":arr1, "B":arr2, "C":arr3, "D":arr4})

df
# Out:
#        A      B      C    D
# 0     54  47937 -63975  872
# 1    505  36879 -25575  721
# 2    770   7467 -41775   46
# 3    779  16530 -14475  582
# 4    458  16758 -22650  838
# ..   ...    ...    ...  ...
# 495  108  18582 -26475  846
# 496  375  14535 -69075  100
# 497  239   7296 -70425  221
# 498  260  49932 -11100  154
# 499  799  21033 -44250  421
#
# [500 rows x 4 columns]

# %%
corr = df.corr(method='pearson')
corr
# Out:
#           A         B         C         D
# A  1.000000 -0.055590  0.003984 -0.021817
# B -0.055590  1.000000  0.041928  0.030197
# C  0.003984  0.041928  1.000000  0.026644
# D -0.021817  0.030197  0.026644  1.000000
